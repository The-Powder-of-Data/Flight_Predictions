# %%
import pandas as pd 
import numpy as np
import datetime

pd.set_option('display.max_columns', None)

#load data
df = pd.read_csv('../../data/db_extracts/flights_test.csv')

# %%
df.head()
# Out:
#          fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  1577862000000                 WN                 WN          WN
# 1  1577862000000                 WN                 WN          WN
# 2  1577862000000                 WN                 WN          WN
# 3  1577862000000                 WN                 WN          WN
# 4  1577862000000                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id origin origin_city_name  dest_airport_id dest  \
# 0              13891    ONT      Ontario, CA            14771  SFO
# ...

# %%
df['month'].unique()
# Out:
# array([1])

# %%
# load data

# add columns

# remove columns
# Out:
# Int64Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#             ...
#             1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970],
#            dtype='int64', name='fl_date', length=660556)
